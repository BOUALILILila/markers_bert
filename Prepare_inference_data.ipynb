# %%
import pandas as pd 

DATA_DIR='/projets/iris/PROJETS/lboualil/workdata/msmarco-passage'
RUN_DIR='/projets/iris/PROJETS/lboualil/workdata/run_files'

# %% [markdown]
# ## Read Run file top1000 with Anserini BM25 with Doc2Qeury

# %%
run=pd.read_csv(f'{RUN_DIR}/run.dev.small.tsv', delimiter='\t', header=None, names=['q_id', 'p_id','rank'])
run.head(10)
# Out:
#       q_id     p_id  rank
# 0  1048585  7187160     1
# 1  1048585  7187157     2
# 2  1048585  7187163     3
# 3  1048585  7187158     4
# 4  1048585  7617404     5
# 5  1048585  7187156     6
# 6  1048585  7187155     7
# 7  1048585  2298838     8
# 8  1048585   574346     9
# 9  1048585  2298839    10

# %% [markdown]
# ## Read qrels file q_id, p_id, label=1

# %%
qrels=pd.read_csv(f'{DATA_DIR}/qrels.dev.small.tsv', delimiter='\t', header=None, names=['q_id','0', 'p_id','label'], usecols=['q_id', 'p_id','label'])
print(qrels.shape)
qrels.sample(10)
# Out:
# (7437, 3)
#          q_id     p_id  label
# 234   1088302  7094594      1
# 6322  1026711  7861043      1
# 206   1088658  7092278      1
# 5811   283344  7795548      1
# 3708   481961  7533440      1
# 4223   662282  7590829      1
# 302   1087327  7102802      1
# 6870  1021639  7713994      1
# 3849   395538  7548990      1
# 7384   208198  8001318      1

# %%
(qrels[(qrels['label']==1)]).shape
# Out:
# (7437, 3)

# %% [markdown]
# ## Read queries file q_id, q_txt

# %%
queries=pd.read_csv(f'{DATA_DIR}/queries.dev.small.tsv', delimiter='\t', header=None, names=['q_id', 'q_txt'])
print(queries.shape)
queries.sample(10)
# Out:
# (6980, 2)
#          q_id                                              q_txt
# 386    275534                    how many books did montag steal
# 5461   995598                        which car brands hold value
# 5775  1085035                  what did daniel fahrenheit invent
# 3052   874299                    what lizards like to be handled
# 1493  1089925                         the bancorp routing number
# 6116   493543                              school age definition
# 1422  1089036                          vasospasms caused by what
# 6954   830649  what is the meaning behind welcome to the blac...
# 1169  1085545                       what county is geneva il in?
# 3936   402427             is an american staffordshire a pitbull

# %%
queries.set_index('q_id', inplace=True, drop=True)
queries.shape
# Out:
# (6980, 1)

# %%
queries=queries.sort_values('q_id')
queries.head(10)
# Out:
#                                                   q_txt
# q_id
# 2                              Androgen receptor define
# 1215  3 levels of government in canada and their res...
# 1288                                          3/5 of 60
# 1576                                    60x40 slab cost
# 2235         Bethel University was founded in what year
# 2798                        Does Suddenlink Carry ESPN3
# 2962  Explain what a bone scan is and what it is use...
# 4696                    Is the Louisiana sales tax 4.75
# 4947                                 Ludacris Net Worth
# 5925              Sony PS-LX300USB how to connect to pc

# %%
queries.loc[478691,:]
# Out:
# q_txt    positive effects of agriculture
# Name: 478691, dtype: object

# %% [markdown]
# ## Read collection/passages p_id, p_txt

# %%
passages = pd.read_csv(f'{DATA_DIR}/collection.tsv', delimiter='\t', header=None, names=['p_id', 'p_txt'])
print(passages.shape)
passages.sample(10)
# Out:
# (8841823, 2)
#             p_id                                              p_txt
# 1103334  1103334  Branding, Identity & Logo Design Explained. A ...
# 1234033  1234033  If you continue to cycle during the month, you...
# 8296941  8296941  1. Make Sure It's Actually a Subpoena. If it i...
# 191623    191623  (Recall from Part 1 of this series that a sche...
# 6328289  6328289  The best way to circulate the warm air is to r...
# 7691105  7691105  Best Answer: Lots of suspects here! It's doubt...
# 7525976  7525976  by Indika. AES vs TKIP. When communicating ove...
# 1141969  1141969  For the city in Florida with movie studios sim...
# 38205      38205  The inside of your bones are filled with a sof...
# 980758    980758  Capillaries are the blood vessels that lead fr...

# %% [markdown]
# ## Merge run, queries, collection to obtain the text of queries and passages

# %%
dff = pd.merge(pd.merge(run, queries, on='q_id'), passages, on='p_id')
print(dff.shape)
dff.sample(10)
# Out:
# (6974598, 5)
#             q_id     p_id  rank  \
# 6390624   478691  3745234   205
# 5972762   717751  7980789   229
# 73838     815421  7947567   923
# 3659234  1100580  4903523   410
# 1316396  1068276  2205995   976
# 195575    689885  2669644   381
# 1832738  1097619   713987    72
# 2905245  1102001  6314158   395
# 2544645   853344  1600504   166
# 2035438   761627  7979686   982
#
#                                                      q_txt  \
# 6390624                    positive effects of agriculture
# 5972762        what is analytical approach to intelligence
# 73838                what is the definition of restatement
# 3659234                              fin de siecle meaning
# 1316396                  what is a rebuttal expert witness
# 195575                                   what is a malanga
# 1832738         how long would the border wall need to be?
# 2905245               why is the whooping crane endangered
# 2544645  what is the weather forecast at this time what...
# 2035438        what is it when your battery loses t charge
#
#                                                      p_txt
# 6390624  As a leading executive in the field of manufac...
# 5972762  10 Smartest Countries in Europe. Published on ...
# 73838    MTS is a file extension for an AVCHD (Advanced...
# 3659234  Sogeti was the original name for the entire Ca...
# 1316396  Note: In hearsay law, witness means someone wh...
# 195575   What impressed me about Ruthless Supplements i...
# 1832738  President Donald Trump has directed the Depart...
# 2905245  1973: With the support of President Richard Ni...
# 2544645  Current U.S. National Radar--Current. The Curr...
# 2035438  Capacity of the charger. Normally, batteries a...

# %%
run.shape[0] == dff.shape[0]
# Out:
# True

# %% [markdown]
# ## Add the column label from qrels

# %%
dffm=pd.merge(dff,qrels,on=['q_id','p_id'])
dff['label']=[0]*dff.shape[0]
dffinal=pd.concat([dffm,dff], sort=False).drop_duplicates(['q_id','p_id'], keep='first')
dffinal.head()
# Out:
#       q_id     p_id  rank                            q_txt  \
# 0  1048585  7187158     4     what is paula deen's brother
# 1  1084602  7126763     4        cast of velvet on netflix
# 2        2  4339068    10         Androgen receptor define
# 3  1048642  7187023    33              what is paranoid sc
# 4   992618  4692413    10  where is seneca south carolina?
#
#                                                p_txt  label
# 0  Paula Deen and her brother Earl W. Bubba Hiers...      1
# 1  Velvet (tv series 2013â2016) - imdb, With pa...      1
# 2  The androgen receptor (AR), also known as NR3C...      1
# 3  Paranoid schizophrenia is a psychotic disorder...      1
# 4  Seneca is a city in Oconee County, South Carol...      1

# %%
dffinal[(dffinal['label']==0)].shape[0] == run.shape[0]-dffm.shape[0]
# Out:
# True

# %%
dfsorted=dffinal.sort_values(by=['q_id','rank'])
dfsorted.reset_index(drop=True, inplace=True)
dfsorted.head(1010)
# Out:
#       q_id     p_id  rank                                              q_txt  \
# 0        2  7035024     1                           Androgen receptor define
# 1        2  1782337     2                           Androgen receptor define
# 2        2  2022782     3                           Androgen receptor define
# 3        2  4339073     4                           Androgen receptor define
# 4        2  4339075     5                           Androgen receptor define
# 5        2  5414414     6                           Androgen receptor define
# 6        2  7496508     7                           Androgen receptor define
# 7        2  3634076     8                           Androgen receptor define
# 8        2  1001873     9                           Androgen receptor define
# 9        2  4339068    10                           Androgen receptor define
# 10       2  6285819    11                           Androgen receptor define
# 11       2  7496506    12                           Androgen receptor define
# 12       2  6285817    13                           Androgen receptor define
# 13       2  2022785    14                           Androgen receptor define
# 14       2  8066640    15                           Androgen receptor define
# 15       2  1001876    16                           Androgen receptor define
# 16       2  4339072    17                           Androgen receptor define
# 17       2  7496507    18                           Androgen receptor define
# 18       2  7496503    19                           Androgen receptor define
# 19       2  6920058    20                           Androgen receptor define
# 20       2  2022779    21                           Androgen receptor define
# 21       2  4339070    22                           Androgen receptor define
# 22       2  2022784    23                           Androgen receptor define
# 23       2   343711    24                           Androgen receptor define
# 24       2  7496505    25                           Androgen receptor define
# 25       2  4339071    26                           Androgen receptor define
# 26       2   413902    27                           Androgen receptor define
# 27       2  1571085    28                           Androgen receptor define
# 28       2  4065727    29                           Androgen receptor define
# 29       2  6887343    30                           Androgen receptor define
# ...    ...      ...   ...                                                ...
# 980      2  7115010   981                           Androgen receptor define
# 981      2  7154092   982                           Androgen receptor define
# 982      2  7382177   983                           Androgen receptor define
# 983      2  8085587   984                           Androgen receptor define
# 984      2  8124747   985                           Androgen receptor define
# 985      2  8523830   986                           Androgen receptor define
# 986      2   916181   987                           Androgen receptor define
# 987      2  1213794   988                           Androgen receptor define
# 988      2  1251760   989                           Androgen receptor define
# 989      2  1350013   990                           Androgen receptor define
# 990      2  1587776   991                           Androgen receptor define
# 991      2  2022056   992                           Androgen receptor define
# 992      2   203465   993                           Androgen receptor define
# 993      2  3317443   994                           Androgen receptor define
# 994      2  3787691   995                           Androgen receptor define
# 995      2   435532   996                           Androgen receptor define
# 996      2  4751091   997                           Androgen receptor define
# 997      2   513610   998                           Androgen receptor define
# 998      2  5394117   999                           Androgen receptor define
# 999      2  5845518  1000                           Androgen receptor define
# 1000  1215  7395960     1  3 levels of government in canada and their res...
# 1001  1215  8783032     2  3 levels of government in canada and their res...
# 1002  1215     5955     3  3 levels of government in canada and their res...
# 1003  1215  7395961     4  3 levels of government in canada and their res...
# 1004  1215  7395967     5  3 levels of government in canada and their res...
# 1005  1215  2859487     6  3 levels of government in canada and their res...
# 1006  1215  7395965     7  3 levels of government in canada and their res...
# 1007  1215  4812725     8  3 levels of government in canada and their res...
# 1008  1215  7395962     9  3 levels of government in canada and their res...
# 1009  1215  3804026    10  3 levels of government in canada and their res...
#
#                                                   p_txt  label
# 0     SRF may bring a number of other proteins to th...      0
# 1     Enzalutamide is an androgen receptor inhibitor...      0
# 2     The androgen dihydrotestosterone binds to the ...      0
# 3     Androgens and androgen receptors (AR) play a p...      0
# 4     During androgen-independent progression, prost...      0
# 5     Most of the androgen receptors on the market h...      0
# 6     Androgens and androgen receptors also have oth...      0
# 7     SARMS or Selective Androgen Receptor Modulator...      0
# 8     The AR gene provides instructions for making a...      0
# 9     The androgen receptor (AR), also known as NR3C...      1
# 10    SARMS stands for selective androgen receptor m...      0
# 11    The binding of an androgen to the androgen rec...      0
# 12    The term SARMS stands for âSelective Androge...      0
# 13    During androgen-dependent progression, prostat...      0
# 14    Molecular Weight(MW): 464.44. Enzalutamide (MD...      0
# 15    Like all steroid hormones, androgens produce e...      0
# 16    In some cell types, testosterone interacts dir...      0
# 17    The gene for the syndrome is on the X chromoso...      0
# 18    The androgen receptor gene is more than 90 kb ...      0
# 19    The AR gene provides instructions for making a...      0
# 20    In addition, deregulated growth factors and cy...      0
# 21    Androgens promote the growth of both normal an...      0
# 22    During androgen-independent progression, prost...      0
# 23    Dihydrotestosterone is actually a more potent ...      0
# 24    Normal function of the androgen receptor. Test...      0
# 25    Normal function of the androgen receptor. Test...      0
# 26    1 Dihydrotestosterone (DHT) is a metabolite of...      0
# 27    She compared their DNA with that of 258 non-tr...      0
# 28    Trenbolone is a highly androgenic steroid, wit...      0
# 29    Spironolactone is a well-known cause of gyneco...      0
# ...                                                 ...    ...
# 980   Neurological conditions like paraplegia, a spi...      0
# 981   corpuscle. 1  Biology. an unattached cell, esp...      0
# 982   [ef-fekÂ´ter] 1  1. an agent that mediates a s...      0
# 983   Hair Cells. Abstract. Hair cells are the senso...      0
# 984   against medical advice antimitochondrial antib...      0
# 985   Stimulus (physiology) The light from the lamp ...      0
# 986   Noun. 1. sensory fiber-a nerve fiber that carr...      0
# 987   Guide. DHEA-S (dehydroepiandrosterone sulfate)...      0
# 988   Therefore, cortisol breaks down muscle protein...      0
# 989   Background. Dehydroepiandrosterone (DHEA) is a...      0
# 990   WOMEN AND STEROIDS. Although there is some ove...      0
# 991   DHT, or dihydrotestosterone, is an androgen ho...      0
# 992   In summary, the adrenal glands disorders consi...      0
# 993   Sex-hormone Producing Tumor. Sex-hormone produ...      0
# 994   Anabolic androgenic steroids are a group of po...      0
# 995   The cause of PCOS is unknown. But most experts...      0
# 996   Steroid is a general term for a class of stron...      0
# 997   Clin Genet 2002: 61: 321â329. C Blackwell Mu...      0
# 998   This test measures the level of sex hormone bi...      0
# 999   Medical Definition of ADRENAL GLAND. : either ...      0
# 1000  In Canada, there are 3 levels of government. E...      1
# 1001  Government in Canada is organized into three a...      0
# 1002  4. Federal System: Finally, in Canada we have ...      0
# 1003  There are three levels of government in Canada...      0
# 1004  4. Social Studies Specific Learning Outcome to...      0
# 1005  Canada is a constitutional monarchy and a parl...      0
# 1006  Federal Government. At the federal level, ther...      0
# 1007  Taxation in Canada. Taxation in Canada is a sh...      0
# 1008  Instruction: 15-20 min1. Canada is a federal s...      0
# 1009  Federal Government. At the federal level, ther...      0
#
# [1010 rows x 6 columns]

# %% [markdown]
# ## How many queries have top1000 docs retrieved

# %%
df1000=dfsorted[(dfsorted['rank']==1000)]
top1000queries=set(df1000['q_id'])

# %%
for q in top1000queries:
    if len(dfsorted[(dfsorted['q_id']==q)])<1000:
        print(q)
        break

# %%
dfsortedtop1000= dfsorted[dfsorted['q_id'].isin(top1000queries)]

# %%
len(dfsortedtop1000[dfsortedtop1000['label']==1])
# Out:
# 6590

# %%
dfsortedtop1000=dfsortedtop1000.sort_values(by=['q_id','rank'])
dfsortedtop1000.shape
# Out:
# (6972000, 6)

# %%
dfsortedtop1000=dfsortedtop1000.reset_index(drop=True)
dfsortedtop1000.head(1010)
# Out:
#       q_id     p_id  rank                                              q_txt  \
# 0        2  7035024     1                           Androgen receptor define
# 1        2  1782337     2                           Androgen receptor define
# 2        2  2022782     3                           Androgen receptor define
# 3        2  4339073     4                           Androgen receptor define
# 4        2  4339075     5                           Androgen receptor define
# 5        2  5414414     6                           Androgen receptor define
# 6        2  7496508     7                           Androgen receptor define
# 7        2  3634076     8                           Androgen receptor define
# 8        2  1001873     9                           Androgen receptor define
# 9        2  4339068    10                           Androgen receptor define
# 10       2  6285819    11                           Androgen receptor define
# 11       2  7496506    12                           Androgen receptor define
# 12       2  6285817    13                           Androgen receptor define
# 13       2  2022785    14                           Androgen receptor define
# 14       2  8066640    15                           Androgen receptor define
# 15       2  1001876    16                           Androgen receptor define
# 16       2  4339072    17                           Androgen receptor define
# 17       2  7496507    18                           Androgen receptor define
# 18       2  7496503    19                           Androgen receptor define
# 19       2  6920058    20                           Androgen receptor define
# 20       2  2022779    21                           Androgen receptor define
# 21       2  4339070    22                           Androgen receptor define
# 22       2  2022784    23                           Androgen receptor define
# 23       2   343711    24                           Androgen receptor define
# 24       2  7496505    25                           Androgen receptor define
# 25       2  4339071    26                           Androgen receptor define
# 26       2   413902    27                           Androgen receptor define
# 27       2  1571085    28                           Androgen receptor define
# 28       2  4065727    29                           Androgen receptor define
# 29       2  6887343    30                           Androgen receptor define
# ...    ...      ...   ...                                                ...
# 980      2  7115010   981                           Androgen receptor define
# 981      2  7154092   982                           Androgen receptor define
# 982      2  7382177   983                           Androgen receptor define
# 983      2  8085587   984                           Androgen receptor define
# 984      2  8124747   985                           Androgen receptor define
# 985      2  8523830   986                           Androgen receptor define
# 986      2   916181   987                           Androgen receptor define
# 987      2  1213794   988                           Androgen receptor define
# 988      2  1251760   989                           Androgen receptor define
# 989      2  1350013   990                           Androgen receptor define
# 990      2  1587776   991                           Androgen receptor define
# 991      2  2022056   992                           Androgen receptor define
# 992      2   203465   993                           Androgen receptor define
# 993      2  3317443   994                           Androgen receptor define
# 994      2  3787691   995                           Androgen receptor define
# 995      2   435532   996                           Androgen receptor define
# 996      2  4751091   997                           Androgen receptor define
# 997      2   513610   998                           Androgen receptor define
# 998      2  5394117   999                           Androgen receptor define
# 999      2  5845518  1000                           Androgen receptor define
# 1000  1215  7395960     1  3 levels of government in canada and their res...
# 1001  1215  8783032     2  3 levels of government in canada and their res...
# 1002  1215     5955     3  3 levels of government in canada and their res...
# 1003  1215  7395961     4  3 levels of government in canada and their res...
# 1004  1215  7395967     5  3 levels of government in canada and their res...
# 1005  1215  2859487     6  3 levels of government in canada and their res...
# 1006  1215  7395965     7  3 levels of government in canada and their res...
# 1007  1215  4812725     8  3 levels of government in canada and their res...
# 1008  1215  7395962     9  3 levels of government in canada and their res...
# 1009  1215  3804026    10  3 levels of government in canada and their res...
#
#                                                   p_txt  label
# 0     SRF may bring a number of other proteins to th...      0
# 1     Enzalutamide is an androgen receptor inhibitor...      0
# 2     The androgen dihydrotestosterone binds to the ...      0
# 3     Androgens and androgen receptors (AR) play a p...      0
# 4     During androgen-independent progression, prost...      0
# 5     Most of the androgen receptors on the market h...      0
# 6     Androgens and androgen receptors also have oth...      0
# 7     SARMS or Selective Androgen Receptor Modulator...      0
# 8     The AR gene provides instructions for making a...      0
# 9     The androgen receptor (AR), also known as NR3C...      1
# 10    SARMS stands for selective androgen receptor m...      0
# 11    The binding of an androgen to the androgen rec...      0
# 12    The term SARMS stands for âSelective Androge...      0
# 13    During androgen-dependent progression, prostat...      0
# 14    Molecular Weight(MW): 464.44. Enzalutamide (MD...      0
# 15    Like all steroid hormones, androgens produce e...      0
# 16    In some cell types, testosterone interacts dir...      0
# 17    The gene for the syndrome is on the X chromoso...      0
# 18    The androgen receptor gene is more than 90 kb ...      0
# 19    The AR gene provides instructions for making a...      0
# 20    In addition, deregulated growth factors and cy...      0
# 21    Androgens promote the growth of both normal an...      0
# 22    During androgen-independent progression, prost...      0
# 23    Dihydrotestosterone is actually a more potent ...      0
# 24    Normal function of the androgen receptor. Test...      0
# 25    Normal function of the androgen receptor. Test...      0
# 26    1 Dihydrotestosterone (DHT) is a metabolite of...      0
# 27    She compared their DNA with that of 258 non-tr...      0
# 28    Trenbolone is a highly androgenic steroid, wit...      0
# 29    Spironolactone is a well-known cause of gyneco...      0
# ...                                                 ...    ...
# 980   Neurological conditions like paraplegia, a spi...      0
# 981   corpuscle. 1  Biology. an unattached cell, esp...      0
# 982   [ef-fekÂ´ter] 1  1. an agent that mediates a s...      0
# 983   Hair Cells. Abstract. Hair cells are the senso...      0
# 984   against medical advice antimitochondrial antib...      0
# 985   Stimulus (physiology) The light from the lamp ...      0
# 986   Noun. 1. sensory fiber-a nerve fiber that carr...      0
# 987   Guide. DHEA-S (dehydroepiandrosterone sulfate)...      0
# 988   Therefore, cortisol breaks down muscle protein...      0
# 989   Background. Dehydroepiandrosterone (DHEA) is a...      0
# 990   WOMEN AND STEROIDS. Although there is some ove...      0
# 991   DHT, or dihydrotestosterone, is an androgen ho...      0
# 992   In summary, the adrenal glands disorders consi...      0
# 993   Sex-hormone Producing Tumor. Sex-hormone produ...      0
# 994   Anabolic androgenic steroids are a group of po...      0
# 995   The cause of PCOS is unknown. But most experts...      0
# 996   Steroid is a general term for a class of stron...      0
# 997   Clin Genet 2002: 61: 321â329. C Blackwell Mu...      0
# 998   This test measures the level of sex hormone bi...      0
# 999   Medical Definition of ADRENAL GLAND. : either ...      0
# 1000  In Canada, there are 3 levels of government. E...      1
# 1001  Government in Canada is organized into three a...      0
# 1002  4. Federal System: Finally, in Canada we have ...      0
# 1003  There are three levels of government in Canada...      0
# 1004  4. Social Studies Specific Learning Outcome to...      0
# 1005  Canada is a constitutional monarchy and a parl...      0
# 1006  Federal Government. At the federal level, ther...      0
# 1007  Taxation in Canada. Taxation in Canada is a sh...      0
# 1008  Instruction: 15-20 min1. Canada is a federal s...      0
# 1009  Federal Government. At the federal level, ther...      0
#
# [1010 rows x 6 columns]

# %%
dfsortedtop1000.to_csv(f'{DATA_DIR}/top1000.doc2query.dev.small.csv')

# %%
dfsortedtop1000[:1000000].to_csv(f'{DATA_DIR}/top1000.doc2query.dev.small_1000queries.csv')

# %%
df=dfsortedtop1000[:1000000]
len(set(df.loc[:,'q_id']))
# Out:
# 1000

# %% [markdown]
# ## Save the query and passage ids in a separate txt file

# %%
dev= pd.read_csv(f'{DATA_DIR}/top1000.doc2query.dev.small_1000queries.csv', index_col=0)
dev.head()
# Out:
#    q_id     p_id  rank                      q_txt  \
# 0     2  7035024     1   Androgen receptor define
# 1     2  1782337     2   Androgen receptor define
# 2     2  2022782     3   Androgen receptor define
# 3     2  4339073     4   Androgen receptor define
# 4     2  4339075     5   Androgen receptor define
#
#                                                p_txt  label
# 0  SRF may bring a number of other proteins to th...      0
# 1  Enzalutamide is an androgen receptor inhibitor...      0
# 2  The androgen dihydrotestosterone binds to the ...      0
# 3  Androgens and androgen receptors (AR) play a p...      0
# 4  During androgen-independent progression, prost...      0

# %%
dev100queries=dev.head(100*1000)
#dev100queries=dev100queries.drop(columns=['q_id','p_id'])
dev100queries.to_csv(f'{DATA_DIR}/top1000.doc2query.dev.small_100queries.csv')

# %%
df= pd.read_csv(f'{DATA_DIR}/marked_top1000.doc2query.dev.small_100queries.csv', index_col=0)
with open(f'{DATA_DIR}/query_doc_ids.top1000.doc2query.dev.small_100queries.txt', 'w') as ids_file:
    for i, row in df.iterrows():
        ids_file.write(f"{row['q_id']}\t{row['p_id']}\n")

# %%
df=df.drop(columns=['q_id','p_id','rank'])
df.head()
# Out:
#                        q_txt  \
# 0   Androgen receptor define
# 1   Androgen receptor define
# 2   Androgen receptor define
# 3   Androgen receptor define
# 4   Androgen receptor define
#
#                                                p_txt  label  \
# 0  SRF may bring a number of other proteins to th...      0
# 1  Enzalutamide is an androgen receptor inhibitor...      0
# 2  The androgen dihydrotestosterone binds to the ...      0
# 3  Androgens and androgen receptors (AR) play a p...      0
# 4  During androgen-independent progression, prost...      0
#
#                                      marked_q  \
# 0  [e0]Androgen[\e0] [e1]receptor[\e1] define
# 1  [e0]Androgen[\e0] [e1]receptor[\e1] define
# 2  [e0]Androgen[\e0] [e1]receptor[\e1] define
# 3  [e0]Androgen[\e0] [e1]receptor[\e1] define
# 4  [e0]Androgen[\e0] [e1]receptor[\e1] define
#
#                                             marked_p
# 0  SRF may bring a number of other proteins to th...
# 1  Enzalutamide is an [e0]androgen[\e0] [e1]recep...
# 2  The [e0]androgen[\e0] dihydrotestosterone bind...
# 3  [e0]Androgens[\e0] and [e0]androgen[\e0] [e1]r...
# 4  During androgen-independent progression , pros...

# %%
df.to_csv(f'{DATA_DIR}/marked_top1000.doc2query.dev.small_100queries_ids_free.csv')

# %%
## Base files without markers

# %%
df= pd.read_csv(f'{DATA_DIR}/top1000.doc2query.dev.small_100queries.csv', index_col=0)
with open(f'{DATA_DIR}/doc2query_run/base/query_doc_ids.top1000.doc2query.dev.small_100queries_no_markers.txt', 'w') as ids_file:
    for i, row in df.iterrows():
        ids_file.write(f"{row['q_id']}\t{row['p_id']}\n")

# %%
df=df.drop(columns=['q_id','p_id','rank'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-bfc6174b0f1f> in <module>
# ----> 1 df=df.drop(columns=['q_id','p_id','rank'])
#       2 df.head(1003)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['q_id' 'p_id' 'rank'] not found in axis"

# %%
df.head(1003)
# Out:
#                                                   q_txt  \
# 0                              Androgen receptor define
# 1                              Androgen receptor define
# 2                              Androgen receptor define
# 3                              Androgen receptor define
# 4                              Androgen receptor define
# 5                              Androgen receptor define
# 6                              Androgen receptor define
# 7                              Androgen receptor define
# 8                              Androgen receptor define
# 9                              Androgen receptor define
# 10                             Androgen receptor define
# 11                             Androgen receptor define
# 12                             Androgen receptor define
# 13                             Androgen receptor define
# 14                             Androgen receptor define
# 15                             Androgen receptor define
# 16                             Androgen receptor define
# 17                             Androgen receptor define
# 18                             Androgen receptor define
# 19                             Androgen receptor define
# 20                             Androgen receptor define
# 21                             Androgen receptor define
# 22                             Androgen receptor define
# 23                             Androgen receptor define
# 24                             Androgen receptor define
# 25                             Androgen receptor define
# 26                             Androgen receptor define
# 27                             Androgen receptor define
# 28                             Androgen receptor define
# 29                             Androgen receptor define
# ...                                                 ...
# 973                            Androgen receptor define
# 974                            Androgen receptor define
# 975                            Androgen receptor define
# 976                            Androgen receptor define
# 977                            Androgen receptor define
# 978                            Androgen receptor define
# 979                            Androgen receptor define
# 980                            Androgen receptor define
# 981                            Androgen receptor define
# 982                            Androgen receptor define
# 983                            Androgen receptor define
# 984                            Androgen receptor define
# 985                            Androgen receptor define
# 986                            Androgen receptor define
# 987                            Androgen receptor define
# 988                            Androgen receptor define
# 989                            Androgen receptor define
# 990                            Androgen receptor define
# 991                            Androgen receptor define
# 992                            Androgen receptor define
# 993                            Androgen receptor define
# 994                            Androgen receptor define
# 995                            Androgen receptor define
# 996                            Androgen receptor define
# 997                            Androgen receptor define
# 998                            Androgen receptor define
# 999                            Androgen receptor define
# 1000  3 levels of government in canada and their res...
# 1001  3 levels of government in canada and their res...
# 1002  3 levels of government in canada and their res...
#
#                                                   p_txt  label
# 0     SRF may bring a number of other proteins to th...      0
# 1     Enzalutamide is an androgen receptor inhibitor...      0
# 2     The androgen dihydrotestosterone binds to the ...      0
# 3     Androgens and androgen receptors (AR) play a p...      0
# 4     During androgen-independent progression, prost...      0
# 5     Most of the androgen receptors on the market h...      0
# 6     Androgens and androgen receptors also have oth...      0
# 7     SARMS or Selective Androgen Receptor Modulator...      0
# 8     The AR gene provides instructions for making a...      0
# 9     The androgen receptor (AR), also known as NR3C...      1
# 10    SARMS stands for selective androgen receptor m...      0
# 11    The binding of an androgen to the androgen rec...      0
# 12    The term SARMS stands for âSelective Androge...      0
# 13    During androgen-dependent progression, prostat...      0
# 14    Molecular Weight(MW): 464.44. Enzalutamide (MD...      0
# 15    Like all steroid hormones, androgens produce e...      0
# 16    In some cell types, testosterone interacts dir...      0
# 17    The gene for the syndrome is on the X chromoso...      0
# 18    The androgen receptor gene is more than 90 kb ...      0
# 19    The AR gene provides instructions for making a...      0
# 20    In addition, deregulated growth factors and cy...      0
# 21    Androgens promote the growth of both normal an...      0
# 22    During androgen-independent progression, prost...      0
# 23    Dihydrotestosterone is actually a more potent ...      0
# 24    Normal function of the androgen receptor. Test...      0
# 25    Normal function of the androgen receptor. Test...      0
# 26    1 Dihydrotestosterone (DHT) is a metabolite of...      0
# 27    She compared their DNA with that of 258 non-tr...      0
# 28    Trenbolone is a highly androgenic steroid, wit...      0
# 29    Spironolactone is a well-known cause of gyneco...      0
# ...                                                 ...    ...
# 973   Freebase(0.00 / 0 votes)Rate this definition: ...      0
# 974   myasthenia gravis myasthenia gravÂ·is (grÄv'Ä...      0
# 975   myasthenia gravÂ·is. (grÄvâ²Ä­s) n. A diseas...      0
# 976   Abstract. Hair cells are the sensory receptors...      0
# 977   distance between the point of x-ray emission i...      0
# 978   1 The first of these approaches defines what i...      0
# 979   Examples of bony in a Sentence. Recent Example...      0
# 980   Neurological conditions like paraplegia, a spi...      0
# 981   corpuscle. 1  Biology. an unattached cell, esp...      0
# 982   [ef-fekÂ´ter] 1  1. an agent that mediates a s...      0
# 983   Hair Cells. Abstract. Hair cells are the senso...      0
# 984   against medical advice antimitochondrial antib...      0
# 985   Stimulus (physiology) The light from the lamp ...      0
# 986   Noun. 1. sensory fiber-a nerve fiber that carr...      0
# 987   Guide. DHEA-S (dehydroepiandrosterone sulfate)...      0
# 988   Therefore, cortisol breaks down muscle protein...      0
# 989   Background. Dehydroepiandrosterone (DHEA) is a...      0
# 990   WOMEN AND STEROIDS. Although there is some ove...      0
# 991   DHT, or dihydrotestosterone, is an androgen ho...      0
# 992   In summary, the adrenal glands disorders consi...      0
# 993   Sex-hormone Producing Tumor. Sex-hormone produ...      0
# 994   Anabolic androgenic steroids are a group of po...      0
# 995   The cause of PCOS is unknown. But most experts...      0
# 996   Steroid is a general term for a class of stron...      0
# 997   Clin Genet 2002: 61: 321â329. C Blackwell Mu...      0
# 998   This test measures the level of sex hormone bi...      0
# 999   Medical Definition of ADRENAL GLAND. : either ...      0
# 1000  In Canada, there are 3 levels of government. E...      1
# 1001  Government in Canada is organized into three a...      0
# 1002  4. Federal System: Finally, in Canada we have ...      0
#
# [1003 rows x 3 columns]

# %%
df.to_csv(f'{DATA_DIR}/doc2query_run/base/top1000.doc2query.dev.small_100queries_ids_free.csv')

# %% [markdown]
# ## complete the <1000 query runs

# %%
df1000=dfsorted[(dfsorted['rank']==1000)]
top1000queries=set(df1000['q_id'])

# %%
all_queries=set(dfsorted.loc[:,'q_id'])
not1000queries=[q for q in all_queries if q not in top1000queries]

# %%
not1000queries= set(not1000queries)

# %%
not1000queries
# Out:
# {405737, 537995, 1088884, 1090291, 1098481, 1099981, 1100010, 1100094}

# %%
dfsortedtop1000= dfsorted[dfsorted['q_id'].isin(top1000queries)]
len(dfsortedtop1000)
# Out:
# 6972000

# %%
NUM_DOCS=1000
for q in not1000queries:
    dfake=pd.DataFrame()
    dff=dfsorted[(dfsorted['q_id']==q)]
    n=max(0,NUM_DOCS-dff.shape[0])
    dfake['q_id']=[q]*n
    dfake['p_id']=["00000000"]*n
    dfake['p_txt']=['FAKE DOCUMENT']*n
    dfake['q_txt']=[queries.loc[q,'q_txt']]*n
    dfake['label']=[0]*n
    dfake['rank']=list(range(dff.shape[0]+1,NUM_DOCS+1))
    dff=dff.append(dfake, ignore_index=True)
    dfsortedtop1000=dfsortedtop1000.append(dff, ignore_index=True)

# %%
dfsortedtop1000.tail(1010)
# Out:
#          label      p_id                                              p_txt  \
# 6978990      0  00000000                                      FAKE DOCUMENT
# 6978991      0  00000000                                      FAKE DOCUMENT
# 6978992      0  00000000                                      FAKE DOCUMENT
# 6978993      0  00000000                                      FAKE DOCUMENT
# 6978994      0  00000000                                      FAKE DOCUMENT
# 6978995      0  00000000                                      FAKE DOCUMENT
# 6978996      0  00000000                                      FAKE DOCUMENT
# 6978997      0  00000000                                      FAKE DOCUMENT
# 6978998      0  00000000                                      FAKE DOCUMENT
# 6978999      0  00000000                                      FAKE DOCUMENT
# 6979000      0   7193391  The overall average patient rating of Dr. Hass...
# 6979001      1   7193390  Visit Dr. Hassan Amjad, an internist & oncolog...
# 6979002      0   7193388  About Dr. Hassan Amjad Dr. Hassan Amjad, MD, B...
# 6979003      0   7193393  Dr. Hassan Amjad is Board Certified in 4 speci...
# 6979004      0   7193394  Dr. Hassan Amjad is an internist in Beckley, W...
# 6979005      0   7193389  Internal Medicine An internist in Beckley, WV,...
# 6979006      0   7193392  Specialties. 1  Internal Medicine An internist...
# 6979007      0    652374  Arabic Meaning: The name Amjad is an Arabic ba...
# 6979008      0    652379  [ 2 syll. a-mjad, am-j- ad ] The baby boy name...
# 6979009      0   2277106  In many cases, though, they end up naming thei...
# 6979010      0    652377  Name Amjad generally means Most excellent or G...
# 6979011      0    652383  Amjad nam merey mother ne rakha, Hussain mery ...
# 6979012      0    652380  Find Amjad meaning and definition at Hamariweb...
# 6979013      0    652375  Amjad /am-jad/ [2 sylls.] as a boys' name is o...
# 6979014      0    947014  A LEADING TEXTILE CLOTH PROCESSING UNIT. Saeed...
# 6979015      0   4082685  Feet) In all other districts of Punjab 1 marla...
# 6979016      0   7193387  Dr. Amjad may employ a variety of diagnostic t...
# 6979017      0   8228271  Hassan Johnson, Actor: Brooklyn's Finest. Hass...
# 6979018      0   6916511  When is Hassan Rouhani's birthday? Hassan Rouh...
# 6979019      0   7773533  Hassan eventually marries Farzana, and has a s...
# ...        ...       ...                                                ...
# 6979970      0  00000000                                      FAKE DOCUMENT
# 6979971      0  00000000                                      FAKE DOCUMENT
# 6979972      0  00000000                                      FAKE DOCUMENT
# 6979973      0  00000000                                      FAKE DOCUMENT
# 6979974      0  00000000                                      FAKE DOCUMENT
# 6979975      0  00000000                                      FAKE DOCUMENT
# 6979976      0  00000000                                      FAKE DOCUMENT
# 6979977      0  00000000                                      FAKE DOCUMENT
# 6979978      0  00000000                                      FAKE DOCUMENT
# 6979979      0  00000000                                      FAKE DOCUMENT
# 6979980      0  00000000                                      FAKE DOCUMENT
# 6979981      0  00000000                                      FAKE DOCUMENT
# 6979982      0  00000000                                      FAKE DOCUMENT
# 6979983      0  00000000                                      FAKE DOCUMENT
# 6979984      0  00000000                                      FAKE DOCUMENT
# 6979985      0  00000000                                      FAKE DOCUMENT
# 6979986      0  00000000                                      FAKE DOCUMENT
# 6979987      0  00000000                                      FAKE DOCUMENT
# 6979988      0  00000000                                      FAKE DOCUMENT
# 6979989      0  00000000                                      FAKE DOCUMENT
# 6979990      0  00000000                                      FAKE DOCUMENT
# 6979991      0  00000000                                      FAKE DOCUMENT
# 6979992      0  00000000                                      FAKE DOCUMENT
# 6979993      0  00000000                                      FAKE DOCUMENT
# 6979994      0  00000000                                      FAKE DOCUMENT
# 6979995      0  00000000                                      FAKE DOCUMENT
# 6979996      0  00000000                                      FAKE DOCUMENT
# 6979997      0  00000000                                      FAKE DOCUMENT
# 6979998      0  00000000                                      FAKE DOCUMENT
# 6979999      0  00000000                                      FAKE DOCUMENT
#
#             q_id         q_txt  rank
# 6978990  1088884   wadi sirhan   991
# 6978991  1088884   wadi sirhan   992
# 6978992  1088884   wadi sirhan   993
# 6978993  1088884   wadi sirhan   994
# 6978994  1088884   wadi sirhan   995
# 6978995  1088884   wadi sirhan   996
# 6978996  1088884   wadi sirhan   997
# 6978997  1088884   wadi sirhan   998
# 6978998  1088884   wadi sirhan   999
# 6978999  1088884   wadi sirhan  1000
# 6979000  1100094  hassan amjad     1
# 6979001  1100094  hassan amjad     2
# 6979002  1100094  hassan amjad     3
# 6979003  1100094  hassan amjad     4
# 6979004  1100094  hassan amjad     5
# 6979005  1100094  hassan amjad     6
# 6979006  1100094  hassan amjad     7
# 6979007  1100094  hassan amjad     8
# 6979008  1100094  hassan amjad     9
# 6979009  1100094  hassan amjad    10
# 6979010  1100094  hassan amjad    11
# 6979011  1100094  hassan amjad    12
# 6979012  1100094  hassan amjad    13
# 6979013  1100094  hassan amjad    14
# 6979014  1100094  hassan amjad    15
# 6979015  1100094  hassan amjad    16
# 6979016  1100094  hassan amjad    17
# 6979017  1100094  hassan amjad    18
# 6979018  1100094  hassan amjad    19
# 6979019  1100094  hassan amjad    20
# ...          ...           ...   ...
# 6979970  1100094  hassan amjad   971
# 6979971  1100094  hassan amjad   972
# 6979972  1100094  hassan amjad   973
# 6979973  1100094  hassan amjad   974
# 6979974  1100094  hassan amjad   975
# 6979975  1100094  hassan amjad   976
# 6979976  1100094  hassan amjad   977
# 6979977  1100094  hassan amjad   978
# 6979978  1100094  hassan amjad   979
# 6979979  1100094  hassan amjad   980
# 6979980  1100094  hassan amjad   981
# 6979981  1100094  hassan amjad   982
# 6979982  1100094  hassan amjad   983
# 6979983  1100094  hassan amjad   984
# 6979984  1100094  hassan amjad   985
# 6979985  1100094  hassan amjad   986
# 6979986  1100094  hassan amjad   987
# 6979987  1100094  hassan amjad   988
# 6979988  1100094  hassan amjad   989
# 6979989  1100094  hassan amjad   990
# 6979990  1100094  hassan amjad   991
# 6979991  1100094  hassan amjad   992
# 6979992  1100094  hassan amjad   993
# 6979993  1100094  hassan amjad   994
# 6979994  1100094  hassan amjad   995
# 6979995  1100094  hassan amjad   996
# 6979996  1100094  hassan amjad   997
# 6979997  1100094  hassan amjad   998
# 6979998  1100094  hassan amjad   999
# 6979999  1100094  hassan amjad  1000
#
# [1010 rows x 6 columns]

# %%
dfsortedtop1000=dfsortedtop1000.sort_values(by=['q_id','rank'])
dfsortedtop1000.shape
# Out:
# (6980000, 6)

# %%
dfsortedtop1000=dfsortedtop1000.reset_index(drop=True)
dfsortedtop1000.head(1010)
# Out:
#       label     p_id                                              p_txt  q_id  \
# 0         0  7035024  SRF may bring a number of other proteins to th...     2
# 1         0  1782337  Enzalutamide is an androgen receptor inhibitor...     2
# 2         0  2022782  The androgen dihydrotestosterone binds to the ...     2
# 3         0  4339073  Androgens and androgen receptors (AR) play a p...     2
# 4         0  4339075  During androgen-independent progression, prost...     2
# 5         0  5414414  Most of the androgen receptors on the market h...     2
# 6         0  7496508  Androgens and androgen receptors also have oth...     2
# 7         0  3634076  SARMS or Selective Androgen Receptor Modulator...     2
# 8         0  1001873  The AR gene provides instructions for making a...     2
# 9         1  4339068  The androgen receptor (AR), also known as NR3C...     2
# 10        0  6285819  SARMS stands for selective androgen receptor m...     2
# 11        0  7496506  The binding of an androgen to the androgen rec...     2
# 12        0  6285817  The term SARMS stands for âSelective Androge...     2
# 13        0  2022785  During androgen-dependent progression, prostat...     2
# 14        0  8066640  Molecular Weight(MW): 464.44. Enzalutamide (MD...     2
# 15        0  1001876  Like all steroid hormones, androgens produce e...     2
# 16        0  4339072  In some cell types, testosterone interacts dir...     2
# 17        0  7496507  The gene for the syndrome is on the X chromoso...     2
# 18        0  7496503  The androgen receptor gene is more than 90 kb ...     2
# 19        0  6920058  The AR gene provides instructions for making a...     2
# 20        0  2022779  In addition, deregulated growth factors and cy...     2
# 21        0  4339070  Androgens promote the growth of both normal an...     2
# 22        0  2022784  During androgen-independent progression, prost...     2
# 23        0   343711  Dihydrotestosterone is actually a more potent ...     2
# 24        0  7496505  Normal function of the androgen receptor. Test...     2
# 25        0  4339071  Normal function of the androgen receptor. Test...     2
# 26        0   413902  1 Dihydrotestosterone (DHT) is a metabolite of...     2
# 27        0  1571085  She compared their DNA with that of 258 non-tr...     2
# 28        0  4065727  Trenbolone is a highly androgenic steroid, wit...     2
# 29        0  6887343  Spironolactone is a well-known cause of gyneco...     2
# ...     ...      ...                                                ...   ...
# 980       0  7115010  Neurological conditions like paraplegia, a spi...     2
# 981       0  7154092  corpuscle. 1  Biology. an unattached cell, esp...     2
# 982       0  7382177  [ef-fekÂ´ter] 1  1. an agent that mediates a s...     2
# 983       0  8085587  Hair Cells. Abstract. Hair cells are the senso...     2
# 984       0  8124747  against medical advice antimitochondrial antib...     2
# 985       0  8523830  Stimulus (physiology) The light from the lamp ...     2
# 986       0   916181  Noun. 1. sensory fiber-a nerve fiber that carr...     2
# 987       0  1213794  Guide. DHEA-S (dehydroepiandrosterone sulfate)...     2
# 988       0  1251760  Therefore, cortisol breaks down muscle protein...     2
# 989       0  1350013  Background. Dehydroepiandrosterone (DHEA) is a...     2
# 990       0  1587776  WOMEN AND STEROIDS. Although there is some ove...     2
# 991       0  2022056  DHT, or dihydrotestosterone, is an androgen ho...     2
# 992       0   203465  In summary, the adrenal glands disorders consi...     2
# 993       0  3317443  Sex-hormone Producing Tumor. Sex-hormone produ...     2
# 994       0  3787691  Anabolic androgenic steroids are a group of po...     2
# 995       0   435532  The cause of PCOS is unknown. But most experts...     2
# 996       0  4751091  Steroid is a general term for a class of stron...     2
# 997       0   513610  Clin Genet 2002: 61: 321â329. C Blackwell Mu...     2
# 998       0  5394117  This test measures the level of sex hormone bi...     2
# 999       0  5845518  Medical Definition of ADRENAL GLAND. : either ...     2
# 1000      1  7395960  In Canada, there are 3 levels of government. E...  1215
# 1001      0  8783032  Government in Canada is organized into three a...  1215
# 1002      0     5955  4. Federal System: Finally, in Canada we have ...  1215
# 1003      0  7395961  There are three levels of government in Canada...  1215
# 1004      0  7395967  4. Social Studies Specific Learning Outcome to...  1215
# 1005      0  2859487  Canada is a constitutional monarchy and a parl...  1215
# 1006      0  7395965  Federal Government. At the federal level, ther...  1215
# 1007      0  4812725  Taxation in Canada. Taxation in Canada is a sh...  1215
# 1008      0  7395962  Instruction: 15-20 min1. Canada is a federal s...  1215
# 1009      0  3804026  Federal Government. At the federal level, ther...  1215
#
#                                                   q_txt  rank
# 0                              Androgen receptor define     1
# 1                              Androgen receptor define     2
# 2                              Androgen receptor define     3
# 3                              Androgen receptor define     4
# 4                              Androgen receptor define     5
# 5                              Androgen receptor define     6
# 6                              Androgen receptor define     7
# 7                              Androgen receptor define     8
# 8                              Androgen receptor define     9
# 9                              Androgen receptor define    10
# 10                             Androgen receptor define    11
# 11                             Androgen receptor define    12
# 12                             Androgen receptor define    13
# 13                             Androgen receptor define    14
# 14                             Androgen receptor define    15
# 15                             Androgen receptor define    16
# 16                             Androgen receptor define    17
# 17                             Androgen receptor define    18
# 18                             Androgen receptor define    19
# 19                             Androgen receptor define    20
# 20                             Androgen receptor define    21
# 21                             Androgen receptor define    22
# 22                             Androgen receptor define    23
# 23                             Androgen receptor define    24
# 24                             Androgen receptor define    25
# 25                             Androgen receptor define    26
# 26                             Androgen receptor define    27
# 27                             Androgen receptor define    28
# 28                             Androgen receptor define    29
# 29                             Androgen receptor define    30
# ...                                                 ...   ...
# 980                            Androgen receptor define   981
# 981                            Androgen receptor define   982
# 982                            Androgen receptor define   983
# 983                            Androgen receptor define   984
# 984                            Androgen receptor define   985
# 985                            Androgen receptor define   986
# 986                            Androgen receptor define   987
# 987                            Androgen receptor define   988
# 988                            Androgen receptor define   989
# 989                            Androgen receptor define   990
# 990                            Androgen receptor define   991
# 991                            Androgen receptor define   992
# 992                            Androgen receptor define   993
# 993                            Androgen receptor define   994
# 994                            Androgen receptor define   995
# 995                            Androgen receptor define   996
# 996                            Androgen receptor define   997
# 997                            Androgen receptor define   998
# 998                            Androgen receptor define   999
# 999                            Androgen receptor define  1000
# 1000  3 levels of government in canada and their res...     1
# 1001  3 levels of government in canada and their res...     2
# 1002  3 levels of government in canada and their res...     3
# 1003  3 levels of government in canada and their res...     4
# 1004  3 levels of government in canada and their res...     5
# 1005  3 levels of government in canada and their res...     6
# 1006  3 levels of government in canada and their res...     7
# 1007  3 levels of government in canada and their res...     8
# 1008  3 levels of government in canada and their res...     9
# 1009  3 levels of government in canada and their res...    10
#
# [1010 rows x 6 columns]

# %%
dfsortedtop1000.to_csv(f"{DATA_DIR}/top1000.doc2query.dev.small_full.csv")

# %%
df= pd.read_csv(f'{DATA_DIR}/top1000.doc2query.dev.small_full.csv', index_col=0)
with open(f'{DATA_DIR}/query_doc_ids.top1000.doc2query.dev.small_full.txt', 'w') as ids_file:
    for i, row in df.iterrows():
        ids_file.write(f"{row['q_id']}\t{row['p_id']}\n")
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df=df.drop(columns=['q_id','p_id','rank'])
df.head()
# Out:
#    label                                              p_txt  \
# 0      0  SRF may bring a number of other proteins to th...
# 1      0  Enzalutamide is an androgen receptor inhibitor...
# 2      0  The androgen dihydrotestosterone binds to the ...
# 3      0  Androgens and androgen receptors (AR) play a p...
# 4      0  During androgen-independent progression, prost...
#
#                        q_txt
# 0   Androgen receptor define
# 1   Androgen receptor define
# 2   Androgen receptor define
# 3   Androgen receptor define
# 4   Androgen receptor define

# %%
df.shape
# Out:
# (6980000, 3)

# %%
df.to_csv(f"{DATA_DIR}/top1000.doc2query.dev.small_full_ids_free.csv")

# %%
df= pd.read_csv(f'{DATA_DIR}/top1000.doc2query.dev.small_full.csv', index_col=0)
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.head(1745000*3+1)
# Out:
#          label     p_id                                              p_txt  \
# 0            0  7035024  SRF may bring a number of other proteins to th...
# 1            0  1782337  Enzalutamide is an androgen receptor inhibitor...
# 2            0  2022782  The androgen dihydrotestosterone binds to the ...
# 3            0  4339073  Androgens and androgen receptors (AR) play a p...
# 4            0  4339075  During androgen-independent progression, prost...
# 5            0  5414414  Most of the androgen receptors on the market h...
# 6            0  7496508  Androgens and androgen receptors also have oth...
# 7            0  3634076  SARMS or Selective Androgen Receptor Modulator...
# 8            0  1001873  The AR gene provides instructions for making a...
# 9            1  4339068  The androgen receptor (AR), also known as NR3C...
# 10           0  6285819  SARMS stands for selective androgen receptor m...
# 11           0  7496506  The binding of an androgen to the androgen rec...
# 12           0  6285817  The term SARMS stands for âSelective Androge...
# 13           0  2022785  During androgen-dependent progression, prostat...
# 14           0  8066640  Molecular Weight(MW): 464.44. Enzalutamide (MD...
# 15           0  1001876  Like all steroid hormones, androgens produce e...
# 16           0  4339072  In some cell types, testosterone interacts dir...
# 17           0  7496507  The gene for the syndrome is on the X chromoso...
# 18           0  7496503  The androgen receptor gene is more than 90 kb ...
# 19           0  6920058  The AR gene provides instructions for making a...
# 20           0  2022779  In addition, deregulated growth factors and cy...
# 21           0  4339070  Androgens promote the growth of both normal an...
# 22           0  2022784  During androgen-independent progression, prost...
# 23           0   343711  Dihydrotestosterone is actually a more potent ...
# 24           0  7496505  Normal function of the androgen receptor. Test...
# 25           0  4339071  Normal function of the androgen receptor. Test...
# 26           0   413902  1 Dihydrotestosterone (DHT) is a metabolite of...
# 27           0  1571085  She compared their DNA with that of 258 non-tr...
# 28           0  4065727  Trenbolone is a highly androgenic steroid, wit...
# 29           0  6887343  Spironolactone is a well-known cause of gyneco...
# ...        ...      ...                                                ...
# 5234971      0  2255855  Harmonization of Capacity Measurement for Port...
# 5234972      0  6332037  unresponsive If someone can't or won't respond...
# 5234973      0  5897146  Answers.com Â® WikiAnswers Â® Categories Liter...
# 5234974      0  8200260  Where are the Cherokee today? The federally re...
# 5234975      0  6533417  The French for 'million' is million; 'a millio...
# 5234976      0  7311029  If TEXAS tried to secede, all that IDIOT PRESI...
# 5234977      0  8218604  The betrayal of the Tutsis in Rwanda was a low...
# 5234978      0  7938233  15 Je suis un crayon rouge. After the 1917 Sov...
# 5234979      0   150098  Watch Kim Jong Un Pilot a Plane. Is there anyt...
# 5234980      0  5761934  United Nations (UN) United Nations (UN), Unite...
# 5234981      0  5970488  It is the main city of one of the most powerfu...
# 5234982      0  6573219  For example, on. the first occasion in measuri...
# 5234983      0  7266309  Media caption Children in the rebel-held Easte...
# 5234984      0  3978725  Hi to all: a friend of mine asked me if I knew...
# 5234985      0  2175085  6 Activated by the Declaration of Independence...
# 5234986      0  2228016  dis-. (dis), This Latin prefix denotes separat...
# 5234987      0   918219  et al means and others. Use it when describing...
# 5234988      0  5155449  The UN's Budgets The UN regular budget provide...
# 5234989      0  7277989  What appears to be one-half of the moon is ill...
# 5234990      0  4358448  Further, pre-kindergarten students can easily ...
# 5234991      0  4674064  In Windows 7 Pro, this works: 1  Open My Compu...
# 5234992      0  8225582  cecmed March 2015 â Present (2 years 11 mont...
# 5234993      0  1377199  Deactivate call forwarding. 1  Perform the Off...
# 5234994      0  4583755  mattybhatter404. matty b is un sucessful 12 ye...
# 5234995      0  5043454  Why are United Nations Interns always unpaid? ...
# 5234996      0  4446199  1 El tamano tamaÃ±o del cerebro del bebe bebÃ©...
# 5234997      0  5655206  â are generally un-negated, while there are ...
# 5234998      0  1562519  Inclusion is an effort to improve quality in e...
# 5234999      0  1469063  a s i a an s i ca un i s ci a s i awww.pekingk...
# 5235000      0  7174386  The main point of the DockPanel is the Dock, a...
#
#             q_id                       q_txt  rank
# 0              2    Androgen receptor define     1
# 1              2    Androgen receptor define     2
# 2              2    Androgen receptor define     3
# 3              2    Androgen receptor define     4
# 4              2    Androgen receptor define     5
# 5              2    Androgen receptor define     6
# 6              2    Androgen receptor define     7
# 7              2    Androgen receptor define     8
# 8              2    Androgen receptor define     9
# 9              2    Androgen receptor define    10
# 10             2    Androgen receptor define    11
# 11             2    Androgen receptor define    12
# 12             2    Androgen receptor define    13
# 13             2    Androgen receptor define    14
# 14             2    Androgen receptor define    15
# 15             2    Androgen receptor define    16
# 16             2    Androgen receptor define    17
# 17             2    Androgen receptor define    18
# 18             2    Androgen receptor define    19
# 19             2    Androgen receptor define    20
# 20             2    Androgen receptor define    21
# 21             2    Androgen receptor define    22
# 22             2    Androgen receptor define    23
# 23             2    Androgen receptor define    24
# 24             2    Androgen receptor define    25
# 25             2    Androgen receptor define    26
# 26             2    Androgen receptor define    27
# 27             2    Androgen receptor define    28
# 28             2    Androgen receptor define    29
# 29             2    Androgen receptor define    30
# ...          ...                         ...   ...
# 5234971  1056437  what is does un stands for   972
# 5234972  1056437  what is does un stands for   973
# 5234973  1056437  what is does un stands for   974
# 5234974  1056437  what is does un stands for   975
# 5234975  1056437  what is does un stands for   976
# 5234976  1056437  what is does un stands for   977
# 5234977  1056437  what is does un stands for   978
# 5234978  1056437  what is does un stands for   979
# 5234979  1056437  what is does un stands for   980
# 5234980  1056437  what is does un stands for   981
# 5234981  1056437  what is does un stands for   982
# 5234982  1056437  what is does un stands for   983
# 5234983  1056437  what is does un stands for   984
# 5234984  1056437  what is does un stands for   985
# 5234985  1056437  what is does un stands for   986
# 5234986  1056437  what is does un stands for   987
# 5234987  1056437  what is does un stands for   988
# 5234988  1056437  what is does un stands for   989
# 5234989  1056437  what is does un stands for   990
# 5234990  1056437  what is does un stands for   991
# 5234991  1056437  what is does un stands for   992
# 5234992  1056437  what is does un stands for   993
# 5234993  1056437  what is does un stands for   994
# 5234994  1056437  what is does un stands for   995
# 5234995  1056437  what is does un stands for   996
# 5234996  1056437  what is does un stands for   997
# 5234997  1056437  what is does un stands for   998
# 5234998  1056437  what is does un stands for   999
# 5234999  1056437  what is does un stands for  1000
# 5235000  1056446  what is dockpanel used for     1
#
# [5235001 rows x 6 columns]

# %%
# TF marked
import pandas as pd 
df= pd.read_csv('/projets/iris/PROJETS/lboualil/workdata/msmarco-passage/TF_Marked_Data/dev/marked_TF_top1000_doc2query_full.csv', index_col=0)
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.head()
# Out:
#    label     p_id                                              p_txt  q_id  \
# 0      0  7035024  SRF may bring a number of other proteins to th...     2
# 1      0  1782337  Enzalutamide is an androgen receptor inhibitor...     2
# 2      0  2022782  The androgen dihydrotestosterone binds to the ...     2
# 3      0  4339073  Androgens and androgen receptors (AR) play a p...     2
# 4      0  4339075  During androgen-independent progression, prost...     2
#
#                        q_txt  rank  \
# 0   Androgen receptor define     1
# 1   Androgen receptor define     2
# 2   Androgen receptor define     3
# 3   Androgen receptor define     4
# 4   Androgen receptor define     5
#
#                                             marked_p  \
# 0  SRF may bring a number of other proteins to th...
# 1  Enzalutamide is an [e0]androgen[\e0] [e1]recep...
# 2  The [e0]androgen[\e0] dihydrotestosterone bind...
# 3  [e0]Androgens[\e0] and [e0]androgen[\e0] [e1]r...
# 4  During androgen-independent progression , pros...
#
#                                      marked_q   stats
# 0  [e0]Androgen[\e0] [e1]receptor[\e1] define  [1, 1]
# 1  [e0]Androgen[\e0] [e1]receptor[\e1] define  [5, 4]
# 2  [e0]Androgen[\e0] [e1]receptor[\e1] define  [3, 2]
# 3  [e0]Androgen[\e0] [e1]receptor[\e1] define  [5, 2]
# 4  [e0]Androgen[\e0] [e1]receptor[\e1] define  [5, 4]

# %%
with open('/projets/iris/PROJETS/lboualil/workdata/msmarco-passage/TF_Marked_Data/dev/query_doc_ids.top1000.doc2query.dev.small_full.txt', 'w') as ids_file:
    for i, row in df.iterrows():
        ids_file.write(f"{row['q_id']}\t{row['p_id']}\n")

# %%
df=df.drop(columns=['q_id','p_id','rank'])
df.to_csv("/projets/iris/PROJETS/lboualil/workdata/msmarco-passage/TF_Marked_Data/dev/marked_TF_top1000_doc2query_full_ids_free.csv")

# %%
d=pd.read_csv("/projets/iris/PROJETS/lboualil/workdata/msmarco-passage/TF_Marked_Data/dev/marked_TF_top1000_doc2query_full_ids_free.csv",index_col=0)

# %%
import pandas as pd
l=[]
for chunk in pd.read_csv(f"/projets/iris/PROJETS/lboualil/workdata/msmarco-passage/TF_Marked_Data/dev/marked_TF_top1000_doc2query_full_ids_free.csv",index_col=0, chunksize=1745000):
  l.append(chunk)
  print(chunk.shape)
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/lib/arraysetops.py:568: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# (1745000, 6)
# (1745000, 6)
# (1745000, 6)
# (1745000, 6)
